# %% [markdown]
# <h1>KAGGLE</h1>

# %% [markdown]
# Micro-Courses
#
# ```
# A.  Python
# Learn the most important language for Data Science
#
#
# B.  Intro to Machine Learning
# Learn the core ideas in machine learning and build your first models
#
#
# C.  Data Visualization: from Non-Coder to Coder
# Make great data visualizations. A great way to see the power of coding!
#
#
# D.  Intermediate Machine Learning
# Learn to handle missing values, non-numeric values, data leakage and more. Your models will be more accurate and useful.
#
#
# E.  Pandas
# Short hands-on challenges to perfect your data manipulation skills
#
#
# F.  Deep Learning
# Use TensorFlow to take Machine Learning to the next level. Your new skills will amaze you.
#
#
# G.  Data Visualization
# Make insightful graphics to see what's happening in your data. Built for users who already program well in Python
#
#
# H.  Intro to SQL
# Learn SQL for working with databases, using Google BigQuery to scale to massive datasets.
#
#
# I.  Microchallenges
# Ultra-short challenges to build and test your skill
#
#
# J.  Embeddings
# Build deep learning models that handle sparse categorical variables
#
#
# K.  Machine Learning Explainability
# Extract human understandable insights from any Machine Learning model
# ```

# %% [markdown]
# <h2>A.  Python</h2>
#
# ```
# Try Daily Delivery!
# 1. Hello, Python
# A quick introduction to Python syntax, variable assignment, and numbers
#
# 2. Exercise: Syntax, Variables, and Numbers
# 3. Functions and Getting Help
# Calling functions and defining our own, and using Python's builtin documentation
#
# 4. Exercise: Functions and Getting Help
# 5. Booleans and Conditionals
# Using booleans for branching logic
#
# 6. Exercise: Booleans and Conditionals
# 7. Lists
# Lists and the things you can do with them. Includes indexing, slicing and mutating
#
# 8. Exercise: Lists
# 9. Loops and List Comprehensions
# For and while loops, and a much-loved Python feature: list comprehensions
#
# 10. Exercise: Loops and List Comprehensions
# 11. Strings and Dictionaries
# Working with strings and dictionaries, two fundamental Python data types
#
# 12. Exercise: Strings and Dictionaries
# 13. Working with External Libraries
# Imports, operator overloading, and survival tips for venturing into the world of external libraries
#
# 14. Exercise: Working with External Libraries
# ```

# %% [markdown]
# <h2>B.  Intro to Machine Learning</h2>
#
# ```
# 1. How Models Work
# The first step if you're new to machine learning
#
# 2. Basic Data Exploration
# Load and understand your data
#
# 3. Exercise: Basic Data Exploration
# 4. Your First Machine Learning Model
# Building your first model. Hurray!
#
# 5. Exercise: Your First Machine Learning Model
# 6. Model Validation
# Measure the performance of your model ? so you can test and compare alternatives
#
# 7. Exercise: Model Validation
# 8. Underfitting and Overfitting
# Fine-tune your model for better performance.
#
# 9. Exercise: Underfitting and Overfitting
# 10. Random Forests
# Using a more sophisticated machine learning algorithm.
#
# 11. Exercise: Random Forests
# 12. Exercise: Machine Learning Competitions
# ```

# %% [markdown]
# <h2>C.  Data Visualization: from Non-Coder to Coder</h2>
#
# ```
# 1. Hello, Seaborn
# Your first introduction to coding for data visualization
#
# 2. Exercise: Hello, Seaborn
# 3. Line Charts
# Visualize trends over time
#
# 4. Exercise: Line Charts
# 5. Bar Charts and Heatmaps
# Use color or length to compare categories in a dataset
#
# 6. Exercise: Bar Charts and Heatmaps
# 7. Scatter Plots
# Leverage the coordinate plane to explore relationships between variables
#
# 8. Exercise: Scatter Plots
# 9. Distributions
# Create histograms and density plots
#
# 10. Exercise: Distributions
# 11. Choosing Plot Types and Custom Styles
# Customize your charts and make them look snazzy
#
# 12. Exercise: Choosing Plot Types and Custom Styles
# 13. Final Project
# Practice for real-world application
#
# 14. Exercise: Final Project
# 15. Creating Your Own Notebooks
# How to put your new skills to use for your next personal or work project
# ```

# %% [markdown]
# <h2>D.  Intermediate Machine Learning</h2>
#
# ```
# 1. Introduction
# Review what you need for this Micro-Course
#
# 2. Exercise: Introduction
# 3. Missing Values
# Missing values happen. Be prepared for this common challenge in real datasets.
#
# 4. Exercise: Missing Values
# 5. Categorical Variables
# There's a lot of non-numeric data out there. Here's how to use it for machine learning
#
# 6. Exercise: Categorical Variables
# 7. Pipelines
# A critical skill for deploying (and even testing) complex models with pre-processing
#
# 8. Exercise: Pipelines
# 9. Cross-Validation
# A better way to test your models
#
# 10. Exercise: Cross-Validation
# 11. XGBoost
# The most accurate modeling technique for structured data
#
# 12. Exercise: XGBoost
# 13. Data Leakage
# Find and fix this problem that ruins your model in subtle ways
#
# 14. Exercise: Data Leakage
# ```

# %% [markdown]
# <h2>E.  Pandas</h2>
#
# ```
# 1. Creating, Reading and Writing
# 2. Indexing, Selecting & Assigning
# 3. Summary Functions and Maps
# 4. Grouping and Sorting
# 5. Data Types and Missing Data
# 6. Renaming and Combining
# ```

# %% [markdown]
# <h2>F.  Deep Learning</h2>
#
# ```
# 1. Intro to DL for Computer Vision
# A quick overview of how models work on images.
#
# 2. Exercise: Intro to DL for Computer Vision
# 3. Building Models From Convolutions
# Scale up from simple building blocks to models with beyond human capabilities.
#
# 4. TensorFlow Programming
# Start writing code using TensorFlow and Keras
#
# 5. Exercise: TensorFlow Programming
# 6. Transfer Learning
# A powerful technique to build highly accurate models even with limited data.
#
# 7. Exercise: Transfer Learning
# 8. Data Augmentation
# Learn a simple trick that effectively increases amount of data available for model training.
#
# 9. Exercise: Data Augmentation
# 10. A Deeper Understanding of Deep Learning
# How Stochastic Gradient Descent and Back-Propagation train your deep learning model.
#
# 11. Deep Learning From Scratch
# Build models without transfer learning. Especially important for uncommon image types.
#
# 12. Exercise: Deep Learning From Scratch
# 13. Dropout and Strides for Larger Models
# Make your models faster and reduce overfitting
#
# 14. Exercise: Dropout and Strides for Larger Models
# ```

# %% [markdown]
# <h2>G.  Data Visualization</h2>
#
# ```
# 1. Welcome to data visualization
# Overview of data visualization tools and course structure.
#
# 2. Univariate plotting with pandas
# Learn the basic (and most important) types of graphs
#
# 3. Bivariate plotting with pandas
# Visually capture the patterns and correlations in any dataset.
#
# 4. Styling your plots
# Make your plots look beautiful ? a key task before sharing
#
# 5. Subplots
# A key concept to make advanced graphics in Python.
#
# 6. Plotting with seaborn
# The faster way to create complex graphics
#
# 7. Faceting with seaborn
# Extend your graphical powers to capture more variables and patterns
#
# 8. Multivariate plotting
# Plotting in high dimensional spaces.
#
# 9. Introduction to plotly (Optional)
# Go from static graphics to interactive data visualization experiences.
#
# 10. Grammar of graphics with plotnine (Optional)
# This Python implementation of R's ggplot2 library provides an incredible level of power for custom graphics.
#
# 11. Time-series plotting (Optional)
# Specialized plots for time-series data
# ```

# %% [markdown]
# <h2>H.  Intro to SQL</h2>
#
# ```
# 1. Getting Started With SQL and BigQuery
# Learn the workflow for handling big datasets with BigQuery and SQL
#
# 2. Exercise: Getting Started With SQL and BigQuery
# 3. Select, From & Where
# The foundational compontents for all SQL queries
#
# 4. Exercise: Select, From & Where
# 5. Group By, Having & Count
# Get more interesting insights directly from your SQL queries
#
# 6. Exercise: Group By, Having & Count
# 7. Order By
# Order your results to focus on the most important data for your use case.
#
# 8. Exercise: Order By
# 9. As & With
# Organize your query for better readability. This becomes especially important for complex queries.
#
# 10. Exercise: As & With
# 11. Joining Data
# Combine data sources. Critical for almost all real-world data problems
#
# 12. Exercise: Joining Data
# ```

# %% [markdown]
# <h2>I.  Microchallenges</h2>
#
# ```
# 1. Blackjack Microchallenge
# 2. Airline Price Optimization Micro-Challenge
# ```

# %% [markdown]
# <h2>J.  Embeddings</h2>
#
# ```
# 1. Embedding Layers
# What's an embedding layer? When would we use one? How do we implement it?
#
# 2. Exercise: Embedding Layers
# 3. Matrix Factorization
# An introduction to an elegant, embedding-based model for solving recommendation-like problems
#
# 4. Exercise: Matrix Factorization
# 5. Exploring Embeddings With Gensim
# Exploring the meaning of learned embeddings using the Gensim library
#
# 6. Exercise: Exploring Embeddings With Gensim
# 7. Visualizing Embeddings With t-SNE
# Visualizing learned embeddings in two dimensions using the t-SNE algorithm
#
# 8. Exercise: Visualizing Embeddings With t-SNE
# ```

# %% [markdown]
# <h2>K.  Machine Learning Explainability</h2>
#
# ```
# 1. Use Cases for Model Insights
# Why and when do you need insights?
#
# 2. Permutation Importance
# What features does your model think are important?
#
# 3. Exercise: Permutation Importance
# 4. Partial Plots
# How does each feature affect your predictions?
#
# 5. Exercise: Partial Plots
# 6. SHAP Values
# Understand individual predictions
#
# 7. Exercise: SHAP Values
# 8. Advanced Uses of SHAP Values
# Aggregate SHAP values for even more detailed model insights
#
# 9. Exercise: Advanced Uses of SHAP Values
# ```
